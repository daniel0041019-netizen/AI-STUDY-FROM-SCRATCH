# %%
# 📅 2026-09-01. OpenAI Chat Completions API 기초
- **학습 일자:** 2026-09-01
- **주요 학습:** OpenAI Client 객체 생성, ChatCompletions 엔드포인트 호출, 응답 데이터(Content) 추출 및 출력

---

### 📌 목차
1. [⚙️ 공통 환경 설정 및 클라이언트 생성](#setup)
2. [📝 Q1. AI 엔지니어 합격 승낙 메일 작성](#q1)
3. [📝 Q2. 한 줄 생산성 팁 요청 및 응답 추출](#q2)

---

# Create a request to the Chat Completions endpoint
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {
            "role": "user",
            "content": "Write a polite reply accepting an AI Engineer job offer."
        }
    ]
)

# 결과 출력
print("[ Q1 실행 결과 ]")
print(response.choices[0].message.content)

# Create a request to the Chat Completions endpoint
response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {"role": "user", "content": "Quick productivity tip."}
    ]
)

# Extract and print the content from the response
print("[ Q2 실행 결과 ]")
print(response.choices[0].message.content)
